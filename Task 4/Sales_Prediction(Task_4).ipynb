# %% [markdown]
# # **Using the advertising dataset given in ISLR and analyse the relationship between 'TV advertising' and 'sales' using a simple linear regression model.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/advertising.csv')

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.shape
# Out:
# (200, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
# correlation between different variables.
sns.heatmap(df.corr(), cmap="YlGnBu", annot = True)
plt.show()

# %%
plt.scatter(df['TV'], df['Sales'])
plt.xlabel("TV - Advertising")
plt.ylabel("Sales")
plt.title("TV Advertising v/s Sales")
plt.show()

# %%
plt.scatter(df['Radio'], df['Sales'])
plt.xlabel("Radio - Advertising")
plt.ylabel("Sales")
plt.title("Radio Advertising v/s Sales")
plt.show()

# %%
plt.scatter(df['Newspaper'], df['Sales'])
plt.xlabel("Newspaper - Advertising")
plt.ylabel("Sales")
plt.title("Newspaper Advertising v/s Sales")
plt.show()

# %% [markdown]
# # **As we clearly infer from the heatmap and scatter plot that sales is majorly dependent upon T.V. Advertising rather than Radio or Newspaper Advertising.**

# %% [markdown]
# # Performing simple linear regression using TV as our feature variable.

# %%
from sklearn.model_selection import train_test_split

# %%
X = df['TV']
y = df['Sales']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 20)

# %%
model = LinearRegression()

# %%
X_train = X_train.values.reshape(-1,1)

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test = X_test.values.reshape(-1,1)
accuracy = model.score(X_test, y_test)
print("Accuracy : {}%".format(accuracy*100))
# Out:
# Accuracy : 81.99796701584714%

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([22.316301  , 20.58469148, 12.37175977, 22.09917128, 20.94295552,
#        18.7716583 , 16.31809245, 12.19262775, 20.10157785,  9.15281166,
#         8.46885303, 13.62025567, 17.45259525,  8.05087832, 18.66852169,
#        22.11002777,  7.30178078, 18.3048294 ,  8.09973251,  8.01288062,
#        20.5629785 , 18.45682021, 13.03943366, 20.28070987, 18.20712103,
#        12.75716503, 19.67817489,  7.50262577,  7.55147996, 17.11604418,
#        12.2740514 , 17.11604418,  8.44171182,  8.53399195, 22.69084977,
#        17.56658835,  9.50564745, 11.94835682, 11.22097225, 16.61664582])

# %%
model.coef_
# Out:
# array([0.05428243])

# %%
model.intercept_
# Out:
# 7.079222818073074

# %%
# plotting regression line
plt.scatter(X_test, y_test)
plt.plot(X_test, 7.079222818073074 + 0.05428243 * X_test, 'r')
plt.show()
